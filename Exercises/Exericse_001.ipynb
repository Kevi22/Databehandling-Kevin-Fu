# %%
import pandas as pd
autos = pd.read_json("../Data/autos.json")
autos
# Out:
#     aspiration   body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 0          std  convertible  3.47        21                9.0         2548
# 1          std  convertible  3.47        21                9.0         2548
# 2          std    hatchback  2.68        19                9.0         2823
# 3          std        sedan  3.19        24               10.0         2337
# 4          std        sedan  3.19        18                8.0         2824
# ..         ...          ...   ...       ...                ...          ...
# 200        std        sedan  3.78        23                9.5         2952
# 201      turbo        sedan  3.78        19                8.7         3049
# 202        std        sedan  3.58        18                8.8         3012
# 203      turbo        sedan  3.01        26               23.0         3217
# 204      turbo        sedan  3.78        19                9.5         3062
#
# ...

# %%
jaguar_cars = autos[autos["make"] == "jaguar"]
autos.query("make == 'jaguar'")
jaguar_count = len(jaguar_cars)
most_expensive_jaguar_price = jaguar_cars['price'].max()

print(f"Number of Jaguar cars: {jaguar_count}")
print(f"Price of the most expensive Jaguar car: {most_expensive_jaguar_price:}")
# Out:
# Number of Jaguar cars: 3
# Price of the most expensive Jaguar car: 36000.0

# %%
toyota_cars = autos[autos["make"] == "toyota"]
autos.query("make == 'toyota'")
toyota_count = len(toyota_cars)
most_expensive_toyota_price = toyota_cars["price"].max()
print(f"Number of Jaguar cars: {toyota_count}")
print(f"Price of the most expensive Jaguar car: {most_expensive_toyota_price:}")
# Out:
# Number of Jaguar cars: 32
# Price of the most expensive Jaguar car: 17669.0

# %%
cars = autos[autos["make"] == ""]
most_expensive_car = ["make"].max()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/kevin/Documents/Github/Databehandling-Kevin-Fu/Exercises/Exericse_001.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/Users/kevin/Documents/Github/Databehandling-Kevin-Fu/Exercises/Exericse_001.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> cars = autos[autos["make"] == ""]
# ----> <a href='vscode-notebook-cell:/Users/kevin/Documents/Github/Databehandling-Kevin-Fu/Exercises/Exericse_001.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> most_expensive_car = ["make"].max()
#
# AttributeError: 'list' object has no attribute 'max'
